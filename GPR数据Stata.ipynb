// %%
cd /Users/mac/Downloads/data // 数据下载地址:https://www.matteoiacoviello.com/gpr_country.htm#country
// Out:
// /Users/mac/Downloads/data

// %%
use data_gpr_export,clear

// %%
%head
// Out:
//      +---------------------------------------------------------------------+
//   1. |  month1 |   month | GPR | GPRT | GPRA  |   GPRH  | GPRHT  |  GPRHA  |
//      |  1900m1 |  1900m1 |   . |    . |    .  |  87.93  | 64.72  | 110.45  |
//      |---------------------------------------------------------------------|
//      | SHARE_~R | N10 | SHARE_~H |    N3H | GPRH_N~W | GPR_NOEW | GPRH_AND |
//      |        . |   . |     3.17 | 7724.0 |    92.19 |        . |   116.95 |
//      |---------------------------------------------------------------------|
//      | GPR_AND | GPRH_B~C  | GPR_BA~C  | SHAREH~1  | SHAREH~2  | SHAREH~3  |
//      |       . |    84.11  |        .  |     0.52  |     0.01  |     0.70  |
//      |---------------------+-----------+-----------+-----------+-----------|
//      | SHAREH~4 | SHAREH~5 | SHAREH~6  | SHAREH~7  | SHAREH~8  | GPRC_ARG  |
//      |     0.00 |     0.00 |     1.32  |     0.95  |     0.00  |        .  |
// ...

// %%
cap drop month1

// gen month1=string(month,"%tm")  // Stata系统时间转换为字符串，方便导出其他设备

// %%
ds
// Out:
// month         SHAREH_CAT_7  GPRC_ITA      GPRHC_ARG     GPRHC_KOR
// GPR           SHAREH_CAT_8  GPRC_JPN      GPRHC_AUS     GPRHC_MEX
// GPRT          GPRC_ARG      GPRC_KOR      GPRHC_BEL     GPRHC_MYS
// GPRA          GPRC_AUS      GPRC_MEX      GPRHC_BRA     GPRHC_NLD
// GPRH          GPRC_BEL      GPRC_MYS      GPRHC_CAN     GPRHC_NOR
// GPRHT         GPRC_BRA      GPRC_NLD      GPRHC_CHE     GPRHC_PER
// GPRHA         GPRC_CAN      GPRC_NOR      GPRHC_CHL     GPRHC_PHL
// SHARE_GPR     GPRC_CHE      GPRC_PER      GPRHC_CHN     GPRHC_POL
// N10           GPRC_CHL      GPRC_PHL      GPRHC_COL     GPRHC_PRT
// SHARE_GPRH    GPRC_CHN      GPRC_POL      GPRHC_DEU     GPRHC_RUS
// N3H           GPRC_COL      GPRC_PRT      GPRHC_DNK     GPRHC_SAU
// GPRH_NOEW     GPRC_DEU      GPRC_RUS      GPRHC_EGY     GPRHC_SWE
// GPR_NOEW      GPRC_DNK      GPRC_SAU      GPRHC_ESP     GPRHC_THA
// GPRH_AND      GPRC_EGY      GPRC_SWE      GPRHC_FIN     GPRHC_TUN
// ...

// %%
list mon* in 1/10
// Out:
//      +-------------------+
//      |   month    month1 |
//      |-------------------|
//   1. |  1900m1    1900m1 |
//   2. |  1900m2    1900m2 |
//   3. |  1900m3    1900m3 |
//   4. |  1900m4    1900m4 |
//   5. |  1900m5    1900m5 |
//      |-------------------|
//   6. |  1900m6    1900m6 |
//   7. |  1900m7    1900m7 |
//   8. |  1900m8    1900m8 |
//   9. |  1900m9    1900m9 |
//  10. | 1900m10   1900m10 |
//      +-------------------+

// %% [markdown]
// ## GPR 画图查看

// %%
tsset month
// Out:
// Time variable: month, 1900m1 to 2024m8
//         Delta: 1 month

// %%
tsline GPR
// Out:
// This front-end cannot display the desired image type.

// %%
tsline GPRC_CHN
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// ### 中美较量

// %%
tsline GPRHC_CHN
// Out:
// This front-end cannot display the desired image type.

// %%
tsline GPRHC_USA
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// ### 俄乌前线

// %%
tsline GPRC_UKR
// Out:
// This front-end cannot display the desired image type.

// %%
tsline GPRC_RUS
// Out:
// This front-end cannot display the desired image type.
