# %%
getwd()
setwd("/Users/mac/MyCode/R WDI数据重塑")
# Out:
# [1] "/Users/mac/MyCode/R WDI数据重塑"

# %%
# library(bruceR)
library(ggplot2)
library(rio)
# library(data.table)

# %%
wdi <- import("/Users/mac/MyCode/R WDI数据重塑/WDI.rds")

wdi
# Out:
#       Country Name Country year AG.AGR.TRAC.NO AG.CON.FERT.PT.ZS AG.CON.FERT.ZS
# 1     Afghanistan  AFG     1960  NA                   NA                NA
# 2     Afghanistan  AFG     1961 120                   NA         0.1437908
# 3     Afghanistan  AFG     1962 150                   NA         0.1428571
# 4     Afghanistan  AFG     1963 200                   NA         0.1419355
# 5     Afghanistan  AFG     1964 200                   NA         0.1410256
# 6     Afghanistan  AFG     1965 300                   NA         0.1410256
# 7     Afghanistan  AFG     1966 400                   NA         0.1914486
# 8     Afghanistan  AFG     1967 500                   NA         1.2748598
# 9     Afghanistan  AFG     1968 500                   NA         1.9122896
# 10    Afghanistan  AFG     1969 550                   NA         2.1628499
# 11    Afghanistan  AFG     1970 550                   NA         2.4650572
# ...

# %%
ggplot(wdi,)
